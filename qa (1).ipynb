# %%
# !ls
# Out:
# sample_data  squad

# %%
# !python3 -m spacy download en_core_web_lg

# %%
# !rm -r squad

# !git clone https://github.com/VladKha/squad.git

# !pip3 install -r squad/requirements.txt
# !python3 -m nltk.downloader -d /usr/share/nltk_data stopwords perluniprops punkt

# !cd squad; sh get_started.sh
# Out:
# rm: cannot remove 'squad': No such file or directory
# Cloning into 'squad'...
# remote: Enumerating objects: 176, done.
# remote: Counting objects: 100% (176/176), done.
# remote: Compressing objects: 100% (116/116), done.
# remote: Total 176 (delta 112), reused 118 (delta 54), pack-reused 0
# Receiving objects: 100% (176/176), 12.99 MiB | 6.51 MiB/s, done.
# Resolving deltas: 100% (112/112), done.
# ...
#     100% |████████████████████████████████| 1.4MB 14.9MB/s
# ...
#     100% |████████████████████████████████| 13.9MB 2.8MB/s
# ...
#     100% |████████████████████████████████| 112kB 31.3MB/s
# ...
#     100% |████████████████████████████████| 993kB 16.6MB/s
# ...
# done
#   Stored in directory: /root/.cache/pip/wheels/d1/ab/40/3bceea46922767e42986aef7606a600538ca80de6062dc266c
# done
#   Stored in directory: /root/.cache/pip/wheels/fb/b4/f5/8ca724b21fc983eee2c9b99a7db69f85480c330a5bf6d8d546
# done
#   Stored in directory: /root/.cache/pip/wheels/fa/d2/9a/d3b6b506c2da98289e5d417215ce34b696db856643bad779f4
# ...

# %%
# !cd squad/data ; zip data.zip dev.answer dev-v2.0.json train.question dev.context train.span dev.question train.answer train-v2.0.json dev.span train.context

print()

# !ls squad/data

print()

from google.colab import files
files.download('squad/data/data.zip')

# %% [markdown]
# # Set up tensorboard

# %%
# !wget https://bin.equinox.io/c/4VmDzA7iaHb/ngrok-stable-linux-amd64.zip
# !unzip ngrok-stable-linux-amd64.zip

# %%
LOG_DIR = 'squad/experiments'
get_ipython().system_raw(
    'tensorboard --logdir {} --host 0.0.0.0 --port 6006 &'
    .format(LOG_DIR)
)

get_ipython().system_raw('./ngrok http 6006 &')

# !curl -s http://localhost:4040/api/tunnels | python3 -c "import sys, json; print(json.load(sys.stdin)['tunnels'][0]['public_url'])"

# %% [markdown]
# # Train

# %%
# !echo '{"installed":{"client_id":"150499756375-nj6nu8daoms3qtnrc67dbdfe7mblv2qd.apps.googleusercontent.com","project_id":"myproject1-223409","auth_uri":"https://accounts.google.com/o/oauth2/auth","token_uri":"https://www.googleapis.com/oauth2/v3/token","auth_provider_x509_cert_url":"https://www.googleapis.com/oauth2/v1/certs","client_secret":"iTtaFtTisf6vLtCvhnhoq8BS","redirect_uris":["urn:ietf:wg:oauth:2.0:oob","http://localhost"]}}' > squad/client_secrets.json

# %%
# !cd squad; python3 code/main.py --experiment_name=baseline --mode=train

# %%
# !ls squad/experiments/baseline

# %% [markdown]
# # Show examples

# %%
# !cd squad ; python3 code/main.py --experiment_name=baseline --mode=show_examples
